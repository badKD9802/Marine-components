# %%
## rag_massages : 대화 이력
## rag_conversations : 대화 세션 관리

# %%
import psycopg2
import pandas as pd

# 1. DB 연결
conn = psycopg2.connect('postgresql://postgres:nb60xg31qnu4rm04v4zvv24htz5580o6@nozomi.proxy.rlwy.net:51615/railway')

# 2. Pandas 옵션 설정 (핵심!)
# 열(Column)의 너비 제한을 없앱니다. None으로 설정하면 전체 텍스트가 다 보입니다.
pd.set_option('display.max_colwidth', None) 
# 행(Row)의 개수도 제한 없이 보고 싶다면 아래 옵션 추가
# pd.set_option('display.max_rows', None)

# 3. 쿼리 실행 및 데이터프레임으로 가져오기
query = 'SELECT * FROM rag_messages'
df = pd.read_sql_query(query, conn)

# 4. 출력
display(df) # print(df) 대신 display(df)를 쓰면 더 예쁘게 나옵니다.

conn.close()
# Out:
# C:\Users\qorud\AppData\Local\Temp\ipykernel_26072\636337927.py:15: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)
#     id  conversation_id       role  \
# 0    1                1       user
# 1    2                1  assistant
# 2    3                1       user
# 3    4                1  assistant
# 4    5                1       user
# 5    6                1  assistant
# 6    7                1       user
# 7    8                1  assistant
# 8    9                1       user
# 9   10                1  assistant
# 10  11                3       user
# 11  12                3  assistant
# 12  13                4       user
# 13  14                4  assistant
#
# ...

# %%
# import psycopg2
# conn = psycopg2.connect('postgresql://postgres:nb60xg31qnu4rm04v4zvv24htz5580o6@nozomi.proxy.rlwy.net:51615/railway')
# cur = conn.cursor()
# cur.execute('SELECT * FROM rag_messages')
# # print(cur.fetchall())
# for r in cur.fetchall():
#     for c in r:
#         print(f' id ={c} |')
#     print('-------------------')
#     # print(f'  id={r[0]} | {r[1]} | {r[2]}') 
# conn.close()
