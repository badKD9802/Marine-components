# %%
import os
from openai import OpenAI

# 1. 클라이언트 설정 (API 키 입력)
client = OpenAI(
    api_key="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" # 여기에 발급받은 API 키를 넣으세요
)

def get_embedding(text, model="text-embedding-3-small"):
    # 2. API 호출
    # 줄바꿈 문자는 임베딩 성능에 영향을 줄 수 있어 공백으로 치환하는 게 좋습니다.
    text = text.replace("\n", " ")
    
    response = client.embeddings.create(
        input=[text], 
        model=model
    )
    
    # 3. 벡터 추출 (실수 리스트 반환)
    return response.data[0].embedding

# --- 테스트 ---
text = "pgvector를 이용해서 벡터 검색을 하고 싶어."
vector = get_embedding(text)

print(f"변환된 벡터 길이: {len(vector)}")  # 1536이 나와야 함
print(f"벡터 데이터(일부): {vector[:5]}...") # [0.012, -0.023, ...] 형태
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[2], line 24
#      22 # --- 테스트 ---
#      23 text = "pgvector를 이용해서 벡터 검색을 하고 싶어."
# ---> 24 vector = get_embedding(text)
#      26 print(f"변환된 벡터 길이: {len(vector)}")  # 1536이 나와야 함
#      27 print(f"벡터 데이터(일부): {vector[:5]}...") # [0.012, -0.023, ...] 형태
#
# Cell In[2], line 14, in get_embedding(text, model)
#       9 def get_embedding(text, model="text-embedding-3-small"):
#      10     # 2. API 호출
#      11     # 줄바꿈 문자는 임베딩 성능에 영향을 줄 수 있어 공백으로 치환하는 게 좋습니다.
#      12     text = text.replace("\n", " ")
# ---> 14     response = client.embeddings.create(
#      15         input=[text],
#      16         model=model
#      17     )
#      19     # 3. 벡터 추출 (실수 리스트 반환)
#      20     return response.data[0].embedding
#
# ...
